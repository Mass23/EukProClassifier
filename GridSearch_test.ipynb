# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from helpers import *
from KernelSVM import *
from LinearSVC import *
from LogReg import *
from RandomForest import *
from NeuralNetworks import *

# %%
# global param
verbose = 1
cv = 2
seed = 42
# %time y, X, ids = load_csv_data("Counts_n10000_k5_s5000.csv")
# Out:
# Loading data...
# Removing rows with less than n_min counts...
# Counts to frequencies...
# Data loaded!
# CPU times: user 34 s, sys: 2.73 s, total: 36.7 s
# Wall time: 36.9 s

# %%
# %time df = grid_search_linSVC(X, y, seed, cv=cv, verbose=verbose)

# %%
# %time df = grid_search_SVC(X, y, seed, cv=cv, verbose=verbose)
# Out:
# Fitting 2 folds for each of 4 candidates, totalling 8 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed: 32.0min finished
# /Users/anita/Documents/EPFL/machine_learning/EukProClassifier/helpers.py:81: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   fig.tight_layout(pad=1)
# /Users/anita/Documents/EPFL/machine_learning/EukProClassifier/helpers.py:82: UserWarning: constrained_layout not applied.  At least one axes collapsed to zero width or height.
#   fig.savefig(figtitle, bbox_inches='tight')
# /Users/anita/Documents/EPFL/machine_learning/EukProClassifier/helpers.py:82: UserWarning: constrained_layout not applied.  At least one axes collapsed to zero width or height.
#   fig.savefig(figtitle, bbox_inches='tight')
#       C  gamma  accuracy  eukaryote accuracy  prokaryote accuracy  \
# 0   1.0    1.0  0.873205            0.845970             0.900440
# 1   1.0   10.0  0.944728            0.940086             0.949370
# 2  10.0    1.0  0.944439            0.939608             0.949270
# 3  10.0   10.0  0.966297            0.961612             0.970983
#
#    learning time  prediction time
# 0     210.076165       205.778397
# 1     111.018896       110.189515
# 2     110.370587       108.333820
# 3      52.654315        50.205652
# CPU times: user 34min 31s, sys: 12 s, total: 34min 43s
# Wall time: 34min 51s
# /Users/anita/opt/anaconda3/lib/python3.7/site-packages/IPython/core/pylabtools.py:132: UserWarning: constrained_layout not applied.  At least one axes collapsed to zero width or height.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# %time df = grid_search_LogReg(X, y, seed, cv=cv, verbose=verbose)

# %%
# %time df = grid_search_RF(X, y, seed, cv=cv, verbose=verbose)

# %%
# %time df = grid_search_NN(X, y, seed, cv=cv, verbose=verbose)
