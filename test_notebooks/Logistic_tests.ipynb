# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from helpers import *
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import make_scorer
from Logistic import *
from time import time

# %%
# global param
verbose = 2
cv = 5
seed = 42
n_jobs = None
y, X, ids = load_csv_data("Counts_n10000_k5_s5000.csv")
# Out:
# Loading data...
# Removing rows with less than n_min counts...
# Counts to frequencies...
# Data loaded!

# %%
t1 = time()
df = grid_search_LogReg(X, y, seed, n_jobs, cv=cv, verbose=verbose, figtitle='plots/LogReg_newton.pdf')
t2 = time()
print(t2-t1)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [CV] C=1.0 ...........................................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] ............................................ C=1.0, total=   3.4s
# [CV] C=1.0 ...........................................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    3.4s remaining:    0.0s
# [CV] ............................................ C=1.0, total=   3.1s
# [CV] C=1.0 ...........................................................
# [CV] ............................................ C=1.0, total=   2.3s
# [CV] C=1.0 ...........................................................
# [CV] ............................................ C=1.0, total=   2.2s
# [CV] C=1.0 ...........................................................
# [CV] ............................................ C=1.0, total=   2.3s
# ...

# %% [markdown]
# No regularization

# %%
rf = LogisticRegression(max_iter=10000, random_state=seed, n_jobs=n_jobs, solver='newton-cg')

# %%
rf = LogisticRegression(penalty='none', max_iter=100)
rf.fit(X, y)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-adc8711136ad> in <module>
#       1 rf = LogisticRegression(penalty='none', max_iter=10000)
# ----> 2 rf.fit(X, y)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1599                       penalty=penalty, max_squared_sum=max_squared_sum,
#    1600                       sample_weight=sample_weight)
# -> 1601             for class_, warm_start_coef_ in zip(classes_, warm_start_coef))
#    1602
#    1603         fold_coefs_, _, n_iter_ = zip(*fold_coefs_)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1002             # remaining jobs.
#    1003             self._iterating = False
# -> 1004             if self.dispatch_one_batch(iterator):
# ...
